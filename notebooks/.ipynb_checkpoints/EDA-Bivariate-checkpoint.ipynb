# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/raw/train.csv')
df.sample(3)
# Out:
#       Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  \
# 1476        4841  9058-MJLZC  Female              0      No         No
# 5143         704  1456-TWCGB    Male              0      No         No
# 4587        6434  6608-QQLVK    Male              0      No         No
#
#       tenure PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 1476      24          Yes            No     Fiber optic  ...               No
# 5143       4          Yes            No             DSL  ...               No
# 4587       1          Yes            No             DSL  ...              Yes
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1476          No         Yes             Yes  Month-to-month              Yes
# 5143          No          No              No  Month-to-month               No
# 4587          No          No              No  Month-to-month              Yes
#
#          PaymentMethod MonthlyCharges TotalCharges  Churn
# 1476  Electronic check          94.60      2283.15     No
# 5143      Mailed check          49.25       208.45     No
# 4587  Electronic check          50.50         50.5    Yes
#
# [3 rows x 22 columns]

# %%
import copy
new_df = copy.deepcopy(df.iloc[:, 1:])

# %%
new_df = new_df.rename(columns = str.lower)

# %%
def bivariate_analysis(df, col, x = None):

    cnt =  df[col].value_counts()

    if x is None:
        ax = sns.countplot(data = df, x = col, color = 'purple', hue = 'churn')
    else:
        ax = sns.countplot(data = df, y = col, color = 'purple', hue = 'churn')
        
    plt.xticks(rotation=45) 
    return plt.show()

# %% [markdown]
# #### Gender vs Churn

# %%
bivariate_analysis(new_df, 'gender')

# %% [markdown]
# #### SeniorCitizen vs Churn

# %%
bivariate_analysis(new_df, 'seniorcitizen')

# %% [markdown]
# #### partner vs churn

# %%
bivariate_analysis(new_df, 'partner')

# %% [markdown]
# #### dependents vs churn

# %%
bivariate_analysis(new_df, 'dependents')

# %% [markdown]
# #### Tenure vs Churn

# %%
churn = new_df.churn.value_counts().index
g = sns.FacetGrid(new_df, row = "churn", row_order = churn,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "tenure")

# %% [markdown]
# #### phoneservice vs churn

# %%
bivariate_analysis(new_df, 'phoneservice')

# %% [markdown]
# #### multiplelines vs churn

# %%
bivariate_analysis(new_df, 'multiplelines')

# %% [markdown]
# #### internetservice vs churn

# %%
bivariate_analysis(new_df, 'internetservice')

# %% [markdown]
# #### onlinesecurity vs churn

# %%
bivariate_analysis(new_df, 'onlinesecurity')

# %% [markdown]
# #### onlinebackup vs churn

# %%
bivariate_analysis(new_df, 'onlinebackup')

# %% [markdown]
# #### deviceprotection vs churn
