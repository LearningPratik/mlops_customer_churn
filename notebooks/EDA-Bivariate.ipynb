# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/raw/train.csv')
df.sample(3)
# Out:
#       Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  \
# 5395        5716  8903-XEBGX    Male              0      No        Yes
# 5220        2843  9371-BITHB  Female              0     Yes        Yes
# 1842         292  2294-SALNE    Male              0     Yes        Yes
#
#       tenure PhoneService MultipleLines InternetService  ...  \
# 5395       2          Yes            No             DSL  ...
# 5220      52          Yes            No              No  ...
# 1842      23          Yes            No     Fiber optic  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5395                   No                   No                   No
# 5220  No internet service  No internet service  No internet service
# 1842                  Yes                  Yes                   No
#
#           StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 5395                  Yes  Month-to-month              Yes  Electronic check
# ...

# %%
df.to_csv('train-l.csv')

# %%
import copy
new_df = copy.deepcopy(df.iloc[:, 1:])

# %%
new_df = new_df.rename(columns = str.lower)

# %%
new_df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
def bivariate_analysis(df, col, x = None):

    cnt =  df[col].value_counts()

    if x is None:
        ax = sns.countplot(data = df, x = col, color = 'purple', hue = 'churn')
    else:
        ax = sns.countplot(data = df, y = col, color = 'purple', hue = 'churn')
        
    plt.xticks(rotation=45) 
    return plt.show()

# %% [markdown]
# #### Gender vs Churn

# %%
bivariate_analysis(new_df, 'gender')

# %% [markdown]
# #### SeniorCitizen vs Churn

# %%
bivariate_analysis(new_df, 'seniorcitizen')

# %% [markdown]
# #### partner vs churn

# %%
bivariate_analysis(new_df, 'partner')

# %% [markdown]
# #### dependents vs churn

# %%
bivariate_analysis(new_df, 'dependents')

# %% [markdown]
# #### Tenure vs Churn

# %%
churn = new_df.churn.value_counts().index
g = sns.FacetGrid(new_df, row = "churn", row_order = churn,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "tenure")

# %% [markdown]
# #### phoneservice vs churn

# %%
bivariate_analysis(new_df, 'phoneservice')

# %% [markdown]
# #### multiplelines vs churn

# %%
bivariate_analysis(new_df, 'multiplelines')

# %% [markdown]
# #### internetservice vs churn

# %%
bivariate_analysis(new_df, 'internetservice')

# %% [markdown]
# #### onlinesecurity vs churn

# %%
bivariate_analysis(new_df, 'onlinesecurity')

# %% [markdown]
# #### onlinebackup vs churn

# %%
bivariate_analysis(new_df, 'onlinebackup')

# %% [markdown]
# #### deviceprotection vs churn

# %%
bivariate_analysis(new_df, 'deviceprotection')

# %% [markdown]
# #### techsupport vs churn

# %%
bivariate_analysis(new_df, 'techsupport')

# %% [markdown]
# #### streamingtv vs churn

# %%
bivariate_analysis(new_df, 'streamingtv')

# %% [markdown]
# #### streamingmovies vs churn

# %%
bivariate_analysis(new_df, 'streamingmovies')

# %% [markdown]
# #### contract vs churn

# %%
bivariate_analysis(new_df, 'contract')

# %% [markdown]
# #### paperlessbilling vs churn

# %%
bivariate_analysis(new_df, 'paperlessbilling')

# %% [markdown]
# #### paymentmethod vs churn

# %%
bivariate_analysis(new_df, 'paymentmethod')

# %% [markdown]
# #### monthlycharges vs churn

# %%
# churn = new_df.churn.value_counts().index
g = sns.FacetGrid(new_df, row = "churn", row_order = churn,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "monthlycharges")

# %% [markdown]
# #### totalcharges vs churn

# %%
new_df['totalcharges'] = pd.to_numeric(new_df['totalcharges'], errors = 'coerce')

# %%
# churn = new_df.churn.value_counts().index
g = sns.FacetGrid(new_df, row = "churn", row_order = churn,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "totalcharges")

# %%
print()
new_df = new_df.dropna()
